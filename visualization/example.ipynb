# %%
import os 
import color_mapping as cm


BASEPATH = os.getcwd()
PARENT_PATH = os.path.dirname(BASEPATH)

surf1 = '1JPZ'
surf2 = '1TQN'

mesh1 = os.path.join(PARENT_PATH, 'data/processed', f'{surf1}/{surf1}.ply')
mesh2 = os.path.join(PARENT_PATH, 'data/processed', f'{surf2}/{surf2}.ply')
c_path = os.path.join(PARENT_PATH, 'results/coupling_matrix', f'{surf1}_{surf2}.npy')


cm.show_color_mapped_meshes(mesh1, mesh2, coupling_matrix_path=c_path)
